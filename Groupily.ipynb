# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/06/kmodes-clustering-algorithm-for-categorical-data/

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from kmodes.kmodes import KModes
from kneed import KneeLocator
import datetime

# %%
# Read the data provided
data = pd.read_csv('person_data.csv')

# %%
# Input from the user, what to take into consideration when forming the groups
cols = ['Experience (Years)', 'Specialty', 'Major']
data2 = data[cols]

# %%
def find_num_clusters(min_clusters, max_clusters, data):
    # Calculate the average cost for each number of clusters
    cost = []
    lowest = 1000000
    K = range(1,10)
    for num_clusters in list(K):
        kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
        kmode.fit_predict(data)
        if kmode.cost_ < lowest:
            lowest = kmode.cost_
        cost.append(kmode.cost_)

    # Elbow curve to find optimal number of clusters
    kneedle = KneeLocator(K, cost, S=1.0, curve="convex", direction="decreasing")
    return kneedle.elbow, lowest

# %%
def find_initial_centroids(lowest, n_clusters, data):
    # Find the lowest cost for each group of initial centroids
    # and return the best one
    current = lowest * 1.5
    time_before = datetime.datetime.now()
    while (current > lowest * 1.15):
        kmode = KModes(n_clusters=n_clusters, init = "random", n_init = 5, verbose=1)
        kmode.fit_predict(data)
        if kmode.cost_ < current:
            current = kmode.cost_
            centroids = kmode._enc_cluster_centroids
        if (datetime.datetime.now() - time_before).seconds > 30:
            break
    return centroids

# %%
def make_clusters(n_clusters, centroids, data):
    # Build the model with the best number of clusters
    # and the initial centroids selected
    kmode = KModes(n_clusters=n_clusters, init = centroids, n_init = 5, verbose=1)
    clusters = kmode.fit_predict(data)
    
    return clusters

# %%
def group_people(data, groups):
    # Iterate through each person in the dataframe and assign them to
    # a group based on the cluster they are in
    person_index = 0
    
    while person_index < data.shape[0]:
        for i in range(0, len(groups)):
            if person_index >= data.shape[0]:
                break
            data.loc[person_index, 'Group'] = groups[i]
            person_index += 1
        i = 0

    return data

# %%
n_clusters, lowest_cost = find_num_clusters(1, 10, data=data2)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 697.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 697.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 697.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 697.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 697.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 29, cost: 608.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 21, cost: 617.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 23, cost: 604.0
# Run 3, iteration: 2/100, moves: 26, cost: 604.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 34, cost: 601.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 608.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 578.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 79, cost: 542.0
# Run 2, iteration: 2/100, moves: 11, cost: 542.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 50, cost: 532.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 77, cost: 547.0
# Run 4, iteration: 2/100, moves: 1, cost: 547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 33, cost: 533.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 53, cost: 485.0
# Run 1, iteration: 2/100, moves: 4, cost: 485.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 510.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 28, cost: 492.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 72, cost: 500.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 97, cost: 495.0
# Run 5, iteration: 2/100, moves: 2, cost: 495.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 41, cost: 472.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 87, cost: 452.0
# Run 2, iteration: 2/100, moves: 2, cost: 452.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 47, cost: 472.0
# Run 3, iteration: 2/100, moves: 3, cost: 472.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 12, cost: 446.0
# Run 4, iteration: 2/100, moves: 7, cost: 446.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 81, cost: 456.0
# Run 5, iteration: 2/100, moves: 28, cost: 456.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves:
0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 500.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 97, cost: 503.0
# Run 1, iteration: 2/100, moves: 5, cost: 503.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 70, cost: 493.0
# Run 2, iteration: 2/100, moves: 3, cost: 493.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 101, cost: 481.0
# Run 3, iteration: 2/100, moves: 3, cost: 481.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 73, cost: 485.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 87, cost: 515.0
# Run 5, iteration: 2/100, moves: 10, cost: 515.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 546.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 72, cost: 501.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 57, cost: 488.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 58, cost: 491.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 100, cost: 474.0
# Run 5, iteration: 2/100, moves: 3, cost: 474.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 49, cost: 495.0
# Run 1, iteration: 2/100, moves: 4, cost: 495.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 105, cost: 470.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 85, cost: 497.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 515.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10, cost: 535.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 83, cost: 477.0
# Run 1, iteration: 2/100, moves: 14, cost: 477.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 519.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 82, cost: 489.0
# Run 3, iteration: 2/100, moves: 38, cost: 489.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 77, cost: 498.0
# Run 4, iteration: 2/100, moves: 5, cost: 498.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 43, cost: 493.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 532.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 32, cost: 507.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 41, cost: 518.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 39, cost: 508.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 516.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 68, cost: 483.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 479.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 94, cost: 498.0
# Run 3, iteration: 2/100, moves: 12, cost: 498.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 60, cost: 488.0
# Run 4, iteration: 2/100, moves: 36, cost: 488.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 23, cost: 501.0
# Best run was number 2

# %%
data['Cluster'] = make_clusters(n_clusters=n_clusters, centroids=best_centroids, data=data2)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 458.0

# %%
# Save the data
data.to_csv('clustered_data.csv')

# %%
# Read the saved data
clustered_data = pd.read_csv('clustered_data.csv')
clustered_data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# User input: number of people per group
people_group = 5

# Find number of groups and make a list of those groups
rows = clustered_data.shape[0]
number_groups = int(rows/people_group)
groups = list(range(1, number_groups))

# %%
clustered_data = clustered_data.sort_values(by='Cluster')
clustered_data['Group'] = -1

# %%
grouped_data = group_people(data=clustered_data, groups=groups)

# %%
clustered_data.sort_values(by='Group',inplace=True)

# %%
clustered_data.drop(columns=['Cluster'], in)
# Out:
#                Name  Experience (Years)  Age   Specialty     Track  \
# 0    Alice Chandler                   2   18    Back-end  Beginner
# 290   Edward Newman                   4   19      Design  Beginner
# 174    Brenda Haley                   3   21  Full-Stack    Policy
# 232   Cameron Fritz                   2   21          AI  Beginner
# 58      Adam Thomas                   2   22    Back-end    Policy
# ..              ...                 ...  ...         ...       ...
# 289      John Duran                   4   17    Business   General
# 115       John Wall                   3   23          AI   General
# 57     Billy Levine                   1   19          AI  Beginner
# 231   Joseph Nelson                   1   17  Full-Stack  Beginner
# 173    Carla Church                   2   23    Back-end  Beginner
#
#                       Major          Minor  Group
# 0         Cognitive Science  Communication      1
# 290              Psychology        Physics      1
# 174        Computer Science  Communication      1
# 232        Computer Science        Finance      1
# 58   Mechanical Engineering        Physics      1
# ..                      ...            ...    ...
# 289              Psychology  Communication     58
# 115                    Math            NaN     58
# 57     Computer Engineering            NaN     58
# 231    Computer Engineering            NaN     58
# 173                    Math        Geology     58
#
# [298 rows x 8 columns]
